# %% [markdown]
# # Задание 1:

# %%
from scipy.misc import derivative
from math import *
def f(x):
    return x**5 + 4*sin(2*x) + cos(3*x+3)
derivative(f, 1.0, dx=1e-6)
# Out:
# 2.509071801881646

# %%
5 * 1 + 8 * cos(2) - 3* sin(3*1 + 3)
# Out:
# 2.5090718022196383

# %%
def f2(x):
    return 5 * (x**4)  + 8 * np.cos(2) - 3* np.sin(3*x + 3)

# %%
derivative(f2, 1.0, dx=1e-6)
# Out:
# 11.358467421063168

# %%
5 * 4 * (1**3) + 0 - 9 * np.cos(3 * 1 + 3)
# Out:
# 11.358467420146706

# %% [markdown]
# # Задание 2:

# %%
def f(x):
    return (np.sin(2*x +1)) ** 5

# %%
import numpy as np
x = np.linspace(-5,5)
fx = f(x)
f1x = [derivative(f, xx, dx=1e-6, n=1) for xx in x]
f2x = [derivative(f, xx, dx=1e-6, n=2) for xx in x]

# %%
import matplotlib.pyplot as plt
plt.plot(x, fx, label='function')
plt.plot(x, f1x, label='derivative')
plt.plot(x, f2x, label='derivative2')
plt.legend()
plt.show()
